# %% [markdown]
# # **Loading Data**

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use("ggplot")
pd.options.display.max_columns = 50
df = pd. read_csv("C:/Users/Nitish B. Singh/Downloads/data2.csv")

# %%
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %% [markdown]
# # **Data Preprocessing**

# %% [markdown]
# ## **Data Preparation**

# %%
df['occupation'].unique()
# Out:
# array(['?', 'Exec-managerial', 'Machine-op-inspct', 'Prof-specialty',
#        'Other-service', 'Adm-clerical', 'Craft-repair',
#        'Transport-moving', 'Handlers-cleaners', 'Sales',
#        'Farming-fishing', 'Tech-support', 'Protective-serv',
#        'Armed-Forces', 'Priv-house-serv'], dtype=object)

# %%
df['native.country'].unique()
# Out:
# array(['United-States', '?', 'Mexico', 'Greece', 'Vietnam', 'China',
#        'Taiwan', 'India', 'Philippines', 'Trinadad&Tobago', 'Canada',
#        'South', 'Holand-Netherlands', 'Puerto-Rico', 'Poland', 'Iran',
#        'England', 'Germany', 'Italy', 'Japan', 'Hong', 'Honduras', 'Cuba',
#        'Ireland', 'Cambodia', 'Peru', 'Nicaragua', 'Dominican-Republic',
#        'Haiti', 'El-Salvador', 'Hungary', 'Columbia', 'Guatemala',
#        'Jamaica', 'Ecuador', 'France', 'Yugoslavia', 'Scotland',
#        'Portugal', 'Laos', 'Thailand', 'Outlying-US(Guam-USVI-etc)'],
#       dtype=object)

# %%
df['native.country'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='native.country'>

# %%
# Plot shows that major population belongs to United-States
df['native.country'] = df['native.country'].apply(lambda x: 'Others' if x!='United-States' else x)

# %%
df['native.country']
# Out:
# 0        United-States
# 1        United-States
# 2        United-States
# 3        United-States
# 4        United-States
#              ...
# 32556    United-States
# 32557    United-States
# 32558    United-States
# 32559    United-States
# 32560    United-States
# Name: native.country, Length: 32561, dtype: object

# %%
df['native.country'].value_counts()
# Out:
# native.country
# United-States    29170
# Others            3391
# Name: count, dtype: int64

# %%
df['sex'] = df['sex'].apply(lambda x: 0 if x =='Male' else 1)

# %%
df['sex']
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 32556    0
# 32557    1
# 32558    0
# 32559    1
# 32560    0
# Name: sex, Length: 32561, dtype: int64

# %%
df['native.country'] = df['native.country'].apply(lambda x: 1 if x == 'United-States' else 0)

# %%
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
df['income'] = df['income'].apply(lambda x: 0 if x =='<=50K' else 1)

# %%
df['race'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='race'>

# %%
# Plot shows that the major population is either white or black
df['race'] = df['race'].apply(lambda x: 'Others' if x!='White' and x!= 'Black' else x)

# %%
df['race'] = df['race'].apply(lambda x: 0 if x=='White' else ( 1 if x=='Black' else 2))

# %%
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'income'],
#       dtype='object')

# %%
df['workclass'].unique()
# Out:
# array(['?', 'Private', 'State-gov', 'Federal-gov', 'Self-emp-not-inc',
#        'Self-emp-inc', 'Local-gov', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
df['workclass'] = df['workclass'].apply(lambda x: 'Government services' if x=='State-gov' or x=='Federal-gov' or x=='Local-gov' else x)

# %%
df['workclass'] = df['workclass'].apply(lambda x: 'No Income' if x=='Never-worked' or x=='Without-pay' else x)

# %%
df['workclass'] = df['workclass'].apply(lambda x: 'Self-employed' if x=='Self-emp-not-inc' or x=='Self-emp-inc' else x)

# %%
df['workclass'] = df['workclass'].apply(lambda x: 0 if x=='No Income' else (1 if x=='Government services' else 2))

# %%
df
# Out:
#        age  workclass  fnlwgt     education  education.num  \
# 0       90          2   77053       HS-grad              9
# 1       82          2  132870       HS-grad              9
# 2       66          2  186061  Some-college             10
# 3       54          2  140359       7th-8th              4
# 4       41          2  264663  Some-college             10
# ...    ...        ...     ...           ...            ...
# 32556   22          2  310152  Some-college             10
# 32557   27          2  257302    Assoc-acdm             12
# 32558   40          2  154374       HS-grad              9
# 32559   58          2  151910       HS-grad              9
# 32560   22          2  201490       HS-grad              9
#
#            marital.status         occupation   relationship  race  sex  \
# 0                 Widowed                  ?  Not-in-family     0    1
# 1                 Widowed    Exec-managerial  Not-in-family     0    1
# ...

# %%
df
# Out:
#        age  workclass  fnlwgt  education.num         occupation  race  sex  \
# 0       90          2   77053              9                  ?     0    1
# 1       82          2  132870              9    Exec-managerial     0    1
# 2       66          2  186061             10                  ?     1    1
# 3       54          2  140359              4  Machine-op-inspct     0    1
# 4       41          2  264663             10     Prof-specialty     0    1
# ...    ...        ...     ...            ...                ...   ...  ...
# 32556   22          2  310152             10    Protective-serv     0    0
# 32557   27          2  257302             12       Tech-support     0    1
# 32558   40          2  154374              9  Machine-op-inspct     0    0
# 32559   58          2  151910              9       Adm-clerical     0    1
# 32560   22          2  201490              9       Adm-clerical     0    0
#
# ...

# %%
df['occupation'].value_counts()
# Out:
# occupation
# Prof-specialty       4140
# Craft-repair         4099
# Exec-managerial      4066
# Adm-clerical         3770
# Sales                3650
# Other-service        3295
# Machine-op-inspct    2002
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1370
# Farming-fishing       994
# Tech-support          928
# Protective-serv       649
# Priv-house-serv       149
# Armed-Forces            9
# Name: count, dtype: int64

# %%
df['age'] = df['age'].apply(lambda x: 0 if x<20 else (1 if x>=20 and x<40 else (2 if x>=40 and x<60 else 3)))
# Out:
# C:\Users\Nitish B. Singh\AppData\Local\Temp\ipykernel_21584\2101504623.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['age'] = df['age'].apply(lambda x: 0 if x<20 else (1 if x>=20 and x<40 else (2 if x>=40 and x<60 else 3)))

# %%
df
# Out:
#        age  workclass  fnlwgt  education.num         occupation  race  sex  \
# 0        3          2   77053              9                  ?     0    1
# 1        3          2  132870              9    Exec-managerial     0    1
# 2        3          2  186061             10                  ?     1    1
# 3        2          2  140359              4  Machine-op-inspct     0    1
# 4        2          2  264663             10     Prof-specialty     0    1
# ...    ...        ...     ...            ...                ...   ...  ...
# 32556    1          2  310152             10    Protective-serv     0    0
# 32557    1          2  257302             12       Tech-support     0    1
# 32558    2          2  154374              9  Machine-op-inspct     0    0
# 32559    2          2  151910              9       Adm-clerical     0    1
# 32560    1          2  201490              9       Adm-clerical     0    0
#
# ...

# %% [markdown]
# ## **Feature Selection**

# %%
df = df[['age', 'workclass', 'fnlwgt', 'education.num',
         #'education', 'marital.status','relationship', 
        'occupation', 'race', 'sex',
       'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
       'income']]

# %%
df = pd.get_dummies(df,columns=['occupation'],dtype=int)            # Splitting occupation into different columns

# %%
df
# Out:
#        age  workclass  fnlwgt  education.num  race  sex  capital.gain  \
# 0        3          2   77053              9     0    1             0
# 1        3          2  132870              9     0    1             0
# 2        3          2  186061             10     1    1             0
# 3        2          2  140359              4     0    1             0
# 4        2          2  264663             10     0    1             0
# ...    ...        ...     ...            ...   ...  ...           ...
# 32556    1          2  310152             10     0    0             0
# 32557    1          2  257302             12     0    1             0
# 32558    2          2  154374              9     0    0             0
# 32559    2          2  151910              9     0    1             0
# 32560    1          2  201490              9     0    0             0
#
#        capital.loss  hours.per.week  native.country  income  occupation_?  \
# ...

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education.num', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'income', 'occupation_?', 'occupation_Adm-clerical',
#        'occupation_Armed-Forces', 'occupation_Craft-repair',
#        'occupation_Exec-managerial', 'occupation_Farming-fishing',
#        'occupation_Handlers-cleaners', 'occupation_Machine-op-inspct',
#        'occupation_Other-service', 'occupation_Priv-house-serv',
#        'occupation_Prof-specialty', 'occupation_Protective-serv',
#        'occupation_Sales', 'occupation_Tech-support',
#        'occupation_Transport-moving'],
#       dtype='object')

# %% [markdown]
# # **Training the Model**

# %% [markdown]
# ## **Data Splitting**

# %%
from sklearn.model_selection import train_test_split
x = df[['age', 'workclass', 'fnlwgt', 'education.num', 'race', 'sex',
       'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
        'occupation_?', 'occupation_Adm-clerical',
       'occupation_Armed-Forces', 'occupation_Craft-repair',
       'occupation_Exec-managerial', 'occupation_Farming-fishing',
       'occupation_Handlers-cleaners', 'occupation_Machine-op-inspct',
       'occupation_Other-service', 'occupation_Priv-house-serv',
       'occupation_Prof-specialty', 'occupation_Protective-serv',
       'occupation_Sales', 'occupation_Tech-support',
       'occupation_Transport-moving']]
y = df[['income']]
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2)

# %% [markdown]
# ## **Model Fitting**

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## **Predicting the values**

# %%
y_pred = regressor.predict(x_test)
df_pred = pd.DataFrame({'Actual':y_test.squeeze(),'Predicted':y_pred.squeeze()})
df_pred
# Out:
#        Actual  Predicted
# 10471       0   0.432477
# 31235       0   0.149914
# 9547        0   0.303860
# 22353       1   0.301066
# 15707       0   0.238741
# ...       ...        ...
# 22138       0   0.651049
# 26168       0   0.169590
# 7513        0   0.239849
# 3306        1   0.630052
# 10761       0   0.026624
#
# [6513 rows x 2 columns]

# %% [markdown]
# # **Evaluating the Model**

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
mae = mean_absolute_error(y_test,y_pred)
mse = mean_squared_error(y_test,y_pred)
print(mae)
print(mse)
# Out:
# 0.2891888962612058
# 0.13286969844599253

# %%
# Here, we can see that we're getting an accuracy of 72% which is good according to the industry standards.
# Hence, this model is applicable.
